# %% [markdown]
# # Task 1
#
# Extract a subset of traning samples from the MNIST handwriten signatures. Create a small convolution neural network with two convolution layers, two pool layers, flatten, dense layer and softmax layer to classify the images. Find out classification error for learning set and testing set.

# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import numpy as np

(x_train,y_train),(x_test,y_test)=tf.keras.datasets.mnist.load_data()

#normalize the images
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
#reshape the images for the CNN
x_train=np.expand_dims(x_train,-1)
x_test=np.expand_dims(x_test,-1)
# extracting a subset of the data
x_train_subset=x_train[:1000]
y_train_subset=y_train[:1000]

model=models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu',input_shape=x_train_subset[0].shape),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Conv2D(filters=64, kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    layers.MaxPool2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(10,activation='relu'),
    layers.Dense(10,activation='softmax')
])

model.compile(optimizer='adam', loss='SparseCategoricalCrossentropy', metrics=['accuracy'])
history=model.fit(x_train_subset,y_train_subset,batch_size=5,epochs=50,validation_data=(x_test,y_test),verbose=1)
train_loss,train_accuracy=model.evaluate(x_train_subset,y_train_subset)
test_loss,test_accuracy=model.evaluate(x_test,y_test)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.2259 - loss: 2.0974 - val_accuracy: 0.4955 - val_loss: 1.4935
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.6171 - loss: 1.1432 - val_accuracy: 0.6670 - val_loss: 0.9661
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7329 - loss: 0.7764 - val_accuracy: 0.7231 - val_loss: 0.8491
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7879 - loss: 0.6218 - val_accuracy: 0.7656 - val_loss: 0.7781
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8816 - loss: 0.4208 - val_accuracy: 0.8183 - val_loss: 0.6286
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9163 - loss: 0.3422 - val_accuracy: 0.8228 - val_loss: 0.6320
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9358 - loss: 0.2384 - val_accuracy: 0.8391 - val_loss: 0.5773
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9390 - loss: 0.2256 - val_accuracy: 0.8238 - val_loss: 0.6633
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9341 - loss: 0.1959 - val_accuracy: 0.8633 - val_loss: 0.5273
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.9632 - loss: 0.1287 - val_accuracy: 0.8629 - val_loss: 0.5533
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9729 - loss: 0.0949 - val_accuracy: 0.8497 - val_loss: 0.6282
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9755 - loss: 0.0805 - val_accuracy: 0.8491 - val_loss: 0.7115
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9811 - loss: 0.0703 - val_accuracy: 0.8642 - val_loss: 0.6430
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9890 - loss: 0.0441 - val_accuracy: 0.8519 - val_loss: 0.7362
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9916 - loss: 0.0401 - val_accuracy: 0.8768 - val_loss: 0.6093
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9997 - loss: 0.0164 - val_accuracy: 0.8691 - val_loss: 0.6722
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8724 - val_loss: 0.6973
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9999 - loss: 0.0071 - val_accuracy: 0.8646 - val_loss: 0.7642
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9740 - loss: 0.0976 - val_accuracy: 0.8711 - val_loss: 0.6394
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9826 - loss: 0.0468 - val_accuracy: 0.8664 - val_loss: 0.6808
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9995 - loss: 0.0175 - val_accuracy: 0.8799 - val_loss: 0.6698
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8848 - val_loss: 0.6630
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8817 - val_loss: 0.6989
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8824 - val_loss: 0.7171
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8808 - val_loss: 0.7408
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8822 - val_loss: 0.7478
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 8.1478e-04 - val_accuracy: 0.8826 - val_loss: 0.7651
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 1.0000 - loss: 7.7989e-04 - val_accuracy: 0.8824 - val_loss: 0.7747
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 7.5318e-04 - val_accuracy: 0.8821 - val_loss: 0.7865
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 1.0000 - loss: 6.1015e-04 - val_accuracy: 0.8817 - val_loss: 0.7971
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 5.1063e-04 - val_accuracy: 0.8828 - val_loss: 0.8114
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 4.5623e-04 - val_accuracy: 0.8826 - val_loss: 0.8225
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 3.7209e-04 - val_accuracy: 0.8826 - val_loss: 0.8304
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 4.2139e-04 - val_accuracy: 0.8818 - val_loss: 0.8440
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 2.8019e-04 - val_accuracy: 0.8830 - val_loss: 0.8500
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 3.4203e-04 - val_accuracy: 0.8829 - val_loss: 0.8583
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 2.7855e-04 - val_accuracy: 0.8823 - val_loss: 0.8751
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 2.3959e-04 - val_accuracy: 0.8820 - val_loss: 0.8897
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 2.1092e-04 - val_accuracy: 0.8839 - val_loss: 0.8914
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 1.5528e-04 - val_accuracy: 0.8819 - val_loss: 0.9090
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 1.5759e-04 - val_accuracy: 0.8823 - val_loss: 0.9185
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 1.4843e-04 - val_accuracy: 0.8823 - val_loss: 0.9257
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 1.1293e-04 - val_accuracy: 0.8824 - val_loss: 0.9381
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 1.1000e-04 - val_accuracy: 0.8835 - val_loss: 0.9426
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 1.0974e-04 - val_accuracy: 0.8832 - val_loss: 0.9555
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 1.0000 - loss: 9.3149e-05 - val_accuracy: 0.8838 - val_loss: 0.9610
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - accuracy: 1.0000 - loss: 7.9925e-05 - val_accuracy: 0.8820 - val_loss: 0.9846
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 1.0000 - loss: 8.5906e-05 - val_accuracy: 0.8824 - val_loss: 0.9904
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 6.8214e-05 - val_accuracy: 0.8816 - val_loss: 1.0008
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 1.0000 - loss: 5.4651e-05 - val_accuracy: 0.8833 - val_loss: 1.0006
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.9530e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8681 - loss: 1.1430

# %%
import matplotlib.pyplot as plt

loss=history.history['loss']
val_loss=history.history['val_loss']
accuracy=history.history['accuracy']
val_accuracy=history.history['val_accuracy']

# Plot loss
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, color='red')
plt.plot(val_loss,color='green')
plt.title('Loss')
plt.ylabel('Loss')

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(accuracy, color='blue')
plt.plot(val_accuracy, color='orange')
plt.title('Accuracy')
plt.ylabel('Accuracy')

# Show the plots
plt.show()

# %% [markdown]
# # Task 2
#
# Create an autoencoder for MNIST fashion dataset. The input and the output is the same image of a number 28x28 pixels.

# %%
# Example
import tensorflow as tf
from tensorflow.keras import models,layers
import numpy as np
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
import random as rnd
import tensorflow as tf
t_x = []
t_y = []
sz = len(train_images) 
for i in range(20):
   idx = rnd.randint(0,sz-1)
   for c in range(10):
     while train_labels[idx] != c:
       idx = rnd.randint(0,sz-1)
     t_x += [np.ndarray.flatten(train_images[idx])]
     t_y += [train_labels[idx]]  

t_x = np.array(t_x, dtype=np.float32)/255.0
test_images=test_images.reshape(-1,784)
test_images.shape
# Out:
# (10000, 784)

# %% [markdown]
# ## Subtask 1
#
#  Use two dense layers (hidden and output). Hidden layer with 2 neurons, output layer with 784 neurons. Plot the response of hidden neurons in scatter plot, number categories distinquish by colors.

# %%
from tensorflow.keras import models,layers,datasets
print(x_train.shape)
autoencoder=models.Sequential([
    layers.InputLayer(shape=(784,)),
    layers.Dense(2,activation='relu'),
    layers.Dense(784,activation='relu')
])

autoencoder.compile(optimizer='adam',loss='mse', metrics=['accuracy'])
history=autoencoder.fit(t_x,t_x,batch_size=5, epochs=10, validation_split=0.2,verbose=1)

encoder=models.Sequential([
    layers.InputLayer(shape=(784,)),
    layers.Dense(2,activation='relu')
])
encoder.set_weights(autoencoder.layers[0].get_weights())

encoded_imgs=encoder.predict(test_images)

plt.figure(figsize=(10,10))
scatter=plt.scatter(encoded_imgs[:,0],encoded_imgs[:,1],c=test_labels, cmap='viridis',alpha=0.5)
plt.colorbar(scatter)
plt.show()
# Out:
# (60000, 784)
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0076 - loss: 0.1711 - val_accuracy: 0.0000e+00 - val_loss: 0.1361
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.1418 - val_accuracy: 0.0000e+00 - val_loss: 0.1254
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.1261 - val_accuracy: 0.0000e+00 - val_loss: 0.1192
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.1236 - val_accuracy: 0.0000e+00 - val_loss: 0.1144
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.1124 - val_accuracy: 0.0000e+00 - val_loss: 0.1111
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.1162 - val_accuracy: 0.0000e+00 - val_loss: 0.1091
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0029 - loss: 0.1123 - val_accuracy: 0.0000e+00 - val_loss: 0.1074
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0081 - loss: 0.1147 - val_accuracy: 0.0000e+00 - val_loss: 0.1065
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0296 - loss: 0.1233 - val_accuracy: 0.0250 - val_loss: 0.1052
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0457 - loss: 0.1108 - val_accuracy: 0.0250 - val_loss: 0.1047
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step

# %% [markdown]
# ## Subtask 2
#
# Modify Subtask 1 so that you add three hidden layers and 2 latent features, i.e.
# 784-10-2-10-784 neurons. Observe differences.

# %%
Write your code here

# %% [markdown]
# ## Subtask 3
#
# Modify Subtask 1 so that you add convolution layers, pooling layers, ... for the autoencoder and observe differences.

# %%
Write your code here

# %% [markdown]
# ## Subtask 4
#
# Extract the decoder from the autoencoder of subtask 1-3 and generate new images based on randomly generated latent features. Plot generated images.

# %%
Write your code here
