# %% [markdown]
# #Test2 - v3
#
# Split the solutions of the sub tasks in Task 1 and 2 into separate cells.

# %% [markdown]
# ##Task1 (16 points)
#
# 1. Load the MNIST image dataset (with the help of Keras functions).
# 2. Reduce the training dataset to 50 images per category and the test dataset to 10 images per category.
# 3. Shuffle both datasets. Normalize input data to the range (<0,1).
# 4. Create the autoencoder model for the reduced dataset with at least two hidden layers in both the encoder and decoder. At least one layer in the encoder will be a Conv2D layer with 30 filters. The dimension of latent space will be 4. Ensure that the output values of the model will be in the range <0,1).
# 5. Train the model with Adam optimizer with learning rate = 0.004 and mse as loss and matrics function. Use 30 epochs, and batch size = 32. Use the test set as validation data during training.
# 6. Split the trained model into an encoder and decoder.
# 7. Use the decoder model to generate four new images based on random values in latent space.
# 8. Display the generated images.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, Conv2D, Flatten, Dense, Conv2DTranspose, Reshape
from keras.optimizers import Adam
from keras import backend as K
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

# Load MNIST dataset
(train_images, _), (test_images, _) = mnist.load_data()

# Reduce the training dataset to 50 images per category and the test dataset to 10 images per category
train_subset = []
test_subset = []
for i in range(10):
    train_subset.append(train_images[train_images == i][:50])
    test_subset.append(test_images[test_images == i][:10])

train_subset = np.concatenate(train_subset)
test_subset = np.concatenate(test_subset)

print(train_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
# Shuffle and normalize
train_subset = shuffle(train_subset, random_state=42)
test_subset = shuffle(test_subset, random_state=42)

train_subset = train_subset.astype('float32') / 255.0
test_subset = test_subset.astype('float32') / 255.0

train_subset = np.expand_dims(train_subset, axis=-1)
test_subset = np.expand_dims(test_subset, axis=-1)

print(train_subset[1])
# Out:
# [0.00392157]

# %%
# Encoder
input_img = Input(shape=784)
x = Conv2D(30, (3, 3), activation='relu', padding='same')(input_img)
x = Flatten()(x)
encoded = Dense(latent_dim, activation='relu')(x)

# Decoder
x = Dense(np.prod(input_shape), activation='sigmoid')(encoded)
x = Reshape(input_shape)(x)
decoded = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(inputs, decoded)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-35cfe9d12448> in <cell line: 3>()
#       1 # Encoder
#       2 input_img = Input(shape=784)
# ----> 3 x = Conv2D(30, (3, 3), activation='relu', padding='same')(input_img)
#       4 x = Flatten()(x)
#       5 encoded = Dense(latent_dim, activation='relu')(x)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     251             ndim = x.shape.rank
# ...

# %%
# Split into encoder
encoder = Model(input_img, encoded)

# %%
autoencoder.compile(optimizer=Adam(learning_rate=0.004), loss='mse', metrics=['accuracy'])

# %%
# Train the model
autoencoder.fit(train_subset, train_subset, epochs=30, batch_size=32, shuffle=True,validation_data=(test_subset, test_subset))
# Out:
# Epoch 1/30
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-c1599a8c4dcf> in <cell line: 2>()
#       1 # Train the model
# ----> 2 autoencoder.fit(train_subset, train_subset, epochs=30, batch_size=32, shuffle=True,validation_data=(test_subset, test_subset))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...

# %%
# Display the generated images
plt.figure(figsize=(8, 4))
for i in range(4):
    ax = plt.subplot(2, 4, i + 1)
    plt.imshow(generated_images[i].numpy().reshape(28, 28), cmap='gray')
    plt.title("Generated Image")
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ##Task 2 (14 points)
#
# 1. Load the dataset from the attached file "rnn.csv".
# 2. Prepare data for the RNN model and set the window size to 8. Use 20 % of the dataset as the test set.
# 3. Create a model with two RNN layers (SimpleRNN), 2 RNN nodes each, capable of predicting the next value from the input dataset. Do not forget to use return sequences.
# 4. Train the model on train set data. Use epochs = 10, batch size = 20. Shuffle the train data.
# 5. Evaluate the model quality on the test set and print the mse value.
# 6. Create the graph of model prediction (output) for the first 15 rows (examples) from the test set.
# 7. Insert the corresponding real values into the same graph to verify the model prediction capabilities.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


data = pd.read_csv('/content/rnn.csv')

display(data)

df = np.array(data['Close'])

plt.plot(df)
print(d)
# Out:
#       Close
# 0     26.84
# 1     26.97
# 2     26.99
# 3     26.91
# 4     26.86
# ...     ...
# 1995  38.36
# 1996  38.70
# 1997  38.11
# 1998  37.61
# 1999  37.22
#
# [2000 rows x 1 columns]
# [26.84 26.97 26.99 ... 38.11 37.61 37.22]

# %%
window_size=8

dx = np.asarray(df, dtype=np.float32)
m=np.max(dx)
x=df/m # normalization

import numpy as np
in_data=np.zeros((len(x)-window_size, window_size))
out_data=np.zeros((len(x)-window_size,1))
for i in range(len(x)-window_size):
  in_data[i]=x[i:i+window_size]
  out_data[i]=x[i+window_size:i+window_size+1]

#print(in_data.shape, out_data.shape)
#print(in_data[:4], out_data[:4])

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(in_data,out_data,test_size=0.2,random_state=123)
print(in_data.shape, out_data.shape)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape )
# Out:
# (1992, 8) (1992, 1)
# (1593, 8) (399, 8)
# (1593, 1) (399, 1)

# %%
epochs=10

model_rnn = tf.keras.models.Sequential([
    tf.keras.layers.SimpleRNN(50, input_shape=(x_train.shape[1],1), return_sequences=True),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.SimpleRNN(40),
    tf.keras.layers.Dense(1)
])
model_rnn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 8, 50)             2600
#
#  dropout (Dropout)           (None, 8, 50)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 40)                3640
#
#  dense (Dense)               (None, 1)                 41
#
# ...
# Total params: 6281 (24.54 KB)
# Trainable params: 6281 (24.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_rnn.compile(loss='mse',  metrics=['accuracy'], optimizer='adam')
history = model_rnn.fit(x_train, y_train, batch_size=20, epochs=epochs, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 80/80 [==============================] - 3s 11ms/step - loss: 0.0017 - accuracy: 6.2775e-04 - val_loss: 1.7458e-04 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 80/80 [==============================] - 1s 7ms/step - loss: 2.6966e-04 - accuracy: 6.2775e-04 - val_loss: 1.6790e-04 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 80/80 [==============================] - 1s 7ms/step - loss: 2.9288e-04 - accuracy: 6.2775e-04 - val_loss: 1.7131e-04 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 80/80 [==============================] - 1s 7ms/step - loss: 2.6868e-04 - accuracy: 6.2775e-04 - val_loss: 2.1113e-04 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 80/80 [==============================] - 1s 7ms/step - loss: 2.9263e-04 - accuracy: 6.2775e-04 - val_loss: 1.7751e-04 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 80/80 [==============================] - 1s 6ms/step - loss: 3.4526e-04 - accuracy: 6.2775e-04 - val_loss: 2.3989e-04 - val_accuracy: 0.0000e+00
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss','accuracy'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss','accuracy'])
plt.show()

# %%
rnn_ibm = model_rnn.predict(x_test)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111)
ax.plot(y_test, label='Real')
plt.plot(rnn_ibm, label='Pred')
plt.legend()
plt.show()
# Out:
# 13/13 [==============================] - 0s 3ms/step
